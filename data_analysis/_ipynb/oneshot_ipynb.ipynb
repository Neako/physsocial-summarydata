# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os
import ast
import re
import seaborn as sns
import inspect

# %%
def color_with_value(val):
    color = 'green' if val < 0.001 else ('orange' if val < 0.01 else 'red')
    return 'background-color: ' + color

# %% [markdown]
# # sum_ipu_lgth_part

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='sum_ipu_lgth_part', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_part']].sort_values(by='sum_ipu_lgth_part')
df[df['sum_ipu_lgth_part'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_part:Agent[T.R]']].sort_values(by='sum_ipu_lgth_part:Agent[T.R]')
df[df['sum_ipu_lgth_part:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # sum_ipu_lgth_conv

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='sum_ipu_lgth_conv', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_conv']].sort_values(by='sum_ipu_lgth_conv')
df[df['sum_ipu_lgth_conv'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_conv:Agent[T.R]']].sort_values(by='sum_ipu_lgth_conv:Agent[T.R]')
df[df['sum_ipu_lgth_conv:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # sum_ipu_lgth_diff

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='sum_ipu_lgth_diff', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_diff']].sort_values(by='sum_ipu_lgth_diff')
df[df['sum_ipu_lgth_diff'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['sum_ipu_lgth_diff:Agent[T.R]']].sort_values(by='sum_ipu_lgth_diff:Agent[T.R]')
df[df['sum_ipu_lgth_diff:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # lexical_richness_part

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='lexical_richness_part', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_part']].sort_values(by='lexical_richness_part')
df[df['lexical_richness_part'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_part:Agent[T.R]']].sort_values(by='lexical_richness_part:Agent[T.R]')
df[df['lexical_richness_part:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # lexical_richness_conv

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='lexical_richness_conv', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_conv']].sort_values(by='lexical_richness_conv')
df[df['lexical_richness_conv'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_conv:Agent[T.R]']].sort_values(by='lexical_richness_conv:Agent[T.R]')
df[df['lexical_richness_conv:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # lexical_richness_diff

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='lexical_richness_diff', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_diff']].sort_values(by='lexical_richness_diff')
df[df['lexical_richness_diff'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['lexical_richness_diff:Agent[T.R]']].sort_values(by='lexical_richness_diff:Agent[T.R]')
df[df['lexical_richness_diff:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # speech_rate_min4_part

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='speech_rate_min4_part', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_part']].sort_values(by='speech_rate_min4_part')
df[df['speech_rate_min4_part'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_part:Agent[T.R]']].sort_values(by='speech_rate_min4_part:Agent[T.R]')
df[df['speech_rate_min4_part:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # speech_rate_min4_conv

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='speech_rate_min4_conv', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_conv']].sort_values(by='speech_rate_min4_conv')
df[df['speech_rate_min4_conv'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_conv:Agent[T.R]']].sort_values(by='speech_rate_min4_conv:Agent[T.R]')
df[df['speech_rate_min4_conv:Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %% [markdown]
# # speech_rate_min4_diff

# %%
CURRENTDIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))))
results = pd.read_excel(os.path.join(CURRENTDIR,"data/pvalues.xlsx"), sheet_name='speech_rate_min4_diff', index_col=0)

# %%
df = results[['Agent[T.R]']].sort_values(by='Agent[T.R]')
df[df['Agent[T.R]'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_diff']].sort_values(by='speech_rate_min4_diff')
df[df['speech_rate_min4_diff'] < 0.05].style.applymap(color_with_value)

# %%
df = results[['speech_rate_min4_diff:Agent[T.R]']].sort_values(by='speech_rate_min4_diff:Agent[T.R]')
df[df['speech_rate_min4_diff:Agent[T.R]'] < 0.05].style.applymap(color_with_value)
